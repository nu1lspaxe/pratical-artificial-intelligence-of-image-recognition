# %%
#掛載GoogleDrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
'用HOG描述子偵測行人'
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

pathname = '/content/gdrive/My Drive/Colab Notebooks/'
filename = 'data/people3.jpg'
src = cv2.imread(pathname + filename)
print('行人')
cv2_imshow(src)

# HOG 特徵描述子
hog = cv2.HOGDescriptor()
# 創建 SVM 檢測器
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
# 檢測行人
(rects, weights) = hog.detectMultiScale(src,
                                        winStride=(4, 4),
                                        padding=(8, 8),
                                        scale=1.25,
                                        useMeanshiftGrouping=False)

print('檢測結果')
for (x,y,w,h) in rects:
    cv2.rectangle(src, (x,y), (x+w,y+h), (0,255,0),2)

cv2_imshow(src)
# Out:
# 行人
# <PIL.Image.Image image mode=RGB size=1200x677 at 0x7F78A2867A58>
# 檢測結果
# <PIL.Image.Image image mode=RGB size=1200x677 at 0x7F78A28674E0>
